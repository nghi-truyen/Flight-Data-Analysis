# %% [markdown]
# # Flight Data Analysis - Airbus

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Removals data

# %% [markdown]
# ### Data set

# %%
Removals = pd.read_excel(r'C:\Users\Nghi Truyen\Desktop\Projet_Recherche_5A\Flight_Data_Analysis\INSA-Airbus FHS - Data set_bis.xlsx', sheet_name='Removals')
Removals.info()
Removals.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2327 entries, 0 to 2326
# Data columns (total 8 columns):
# Customer                         2327 non-null int64
# Removal date                     2327 non-null datetime64[ns]
# P/N                              2327 non-null object
# Description                      2327 non-null object
# S/N                              2327 non-null object
# Maintenance Type                 2327 non-null object
# TSI (Flight Hours) at removal    2237 non-null float64
# TSN (Flight Hours) at Removal    2277 non-null float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 145.5+ KB
#    Customer Removal date P/N Description          S/N Maintenance Type  \
# 0         3   2015-01-01   C        PN_C  15323054356      Unscheduled
# 1         3   2015-01-01   C        PN_C  15323057041      Unscheduled
# 2         3   2015-01-03   C        PN_C  15323072973      Unscheduled
# 3         3   2015-01-07   C        PN_C  15323053425      Unscheduled
# 4         3   2015-01-07   C        PN_C  15323058236      Unscheduled
#
#    TSI (Flight Hours) at removal  TSN (Flight Hours) at Removal
# 0                         5819.0                         5819.0
# 1                         5819.0                         5819.0
# 2                         3036.0                         3036.0
# 3                         5614.0                         5614.0
# 4                         5614.0                         5614.0

# %%
Customer = "Customer"
Date = "Removal date"
PN = "P/N"
Descrip = "Description"
SN = "S/N"
Maintenance = "Maintenance Type"
TSI = "TSI (Flight Hours) at removal"
TSN = "TSN (Flight Hours) at Removal"

# %% [markdown]
# ### Data visualization

# %%
plt.hist(Removals[TSI].replace(np.nan, 0.0),bins=10)
plt.ylabel('Frequency')
plt.xlabel('Hour ageing since installation')
plt.title('Time since installation for 3 types A, B and C')
plt.figure()
plt.hist(Removals[TSN].replace(np.nan, 0.0),bins=10)
plt.ylabel('Frequency')
plt.xlabel('Hour ageing since new')
plt.title('Time since new for 3 types A, B and C')
# Out:
# Text(0.5,1,'Time since new for 3 types A, B and C')

# %%
plt.hist(Removals[Removals[PN]=='A'][TSI].replace(np.nan, 0.0),bins=10)
plt.ylabel('Frequency')
plt.xlabel('Hour ageing since installation')
plt.title('Time since installation of type A')
plt.figure()
plt.hist(Removals[Removals[PN]=='A'][TSN].replace(np.nan, 0.0),bins=10)
plt.ylabel('Frequency')
plt.xlabel('Hour ageing since new')
plt.title('Time since new of type A')
# Out:
# Text(0.5,1,'Time since new of type A')

# %%
plt.hist(Removals[Removals[PN]=='B'][TSI].replace(np.nan, 0.0),bins=10)
plt.ylabel('Frequency')
plt.xlabel('Hour ageing since installation')
plt.title('Time since installation of type B')
plt.figure()
plt.hist(SN_list[SN_list[PN]=='B'][TSN].replace(np.nan, 0.0),bins=10)
plt.ylabel('Frequency')
plt.xlabel('Hour ageing since new')
plt.title('Time since new of type B')
# Out:
# Text(0.5,1,'Time since new of type B')

# %%
len(Removals[Removals[Maintenance] == 'Unscheduled'])/np.sum(Removals[TSI])
# Out:
# 7.367149876584417e-05

# %%
plt.hist(Removals[Removals[PN]=='C'][TSI].replace(np.nan, 0.0),bins=10)
plt.ylabel('Frequency')
plt.xlabel('Hour ageing since installation')
plt.title('Time since installation of type C')
plt.figure()
plt.hist(Removals[Removals[PN]=='C'][TSN].replace(np.nan, 0.0),bins=10)
plt.ylabel('Frequency')
plt.xlabel('Hour ageing since new')
plt.title('Time since new of type C')
# Out:
# Text(0.5,1,'Time since new of type C')

# %% [markdown]
# ## SN_list data

# %% [markdown]
# ### Data set

# %%
SN_list = pd.read_excel(r'C:\Users\Nghi Truyen\Desktop\Projet_Recherche_5A\Flight_Data_Analysis\INSA-Airbus FHS - Data set_bis.xlsx', sheet_name='SN list')
SN_list.info()
SN_list.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5708 entries, 0 to 5707
# Data columns (total 8 columns):
# Part Number                       5708 non-null object
# Description                       5708 non-null object
# Serial Number                     5708 non-null object
# Current SN Status Description     5708 non-null object
# Company                           5705 non-null object
# Hour ageing Since Installation    5708 non-null float64
# Hour ageing Since New             5708 non-null float64
# Since New Date                    4273 non-null object
# dtypes: float64(2), object(6)
# memory usage: 356.8+ KB
#   Part Number Description Serial Number Current SN Status Description Company  \
# 0           A        PN_A  XXXM01-00324                   On Aircraft       5
# 1           A        PN_A  XXXM01-00329                   On Aircraft       5
# 2           A        PN_A  XXXM01-00334                   On Aircraft       5
# 3           A        PN_A  XXXM01-00337                   On Aircraft       5
# 4           A        PN_A  XXXM01-00338                   On Aircraft       5
#
#    Hour ageing Since Installation  Hour ageing Since New       Since New Date
# 0                        39498.39               54222.37  2007-11-19 00:00:00
# 1                        54525.41               54525.41  2007-11-19 00:00:00
# 2                        32238.92               52831.08  2008-03-12 00:00:00
# 3                         6951.19               52169.46  2006-04-01 00:00:00
# 4                        55511.55               55511.55  2008-03-12 00:00:00

# %%
PN = "Part Number"
SN = "Serial Number"
Description = "Description"
Status = "Current SN Status Description"
Company = "Company"
TSI = "Hour ageing Since Installation"
TSN = "Hour ageing Since New"
SND = "Since New Date"

# %% [markdown]
# ### Data visualization

# %%
plt.hist(SN_list[TSI],bins=20)
plt.ylabel('Frequency')
plt.xlabel('Hour ageing since installation')
plt.title('Time since installation for 3 types A, B and C')
plt.figure()
plt.hist(SN_list[TSN],bins=20)
plt.ylabel('Frequency')
plt.xlabel('Hour ageing since new')
plt.title('Time since new for 3 types A, B and C')
# Out:
# Text(0.5,1,'Time since new for 3 types A, B and C')

# %%
plt.hist(SN_list[SN_list[PN]=='A'][TSI],bins=20)
plt.ylabel('Frequency')
plt.xlabel('Hour ageing since installation')
plt.title('Time since installation of type A')
plt.figure()
plt.hist(SN_list[SN_list[PN]=='A'][TSN],bins=20)
plt.ylabel('Frequency')
plt.xlabel('Hour ageing since new')
plt.title('Time since new of type A')
# Out:
# Text(0.5,1,'Time since new of type A')

# %%
plt.hist(SN_list[SN_list[PN]=='B'][TSI],bins=20)
plt.ylabel('Frequency')
plt.xlabel('Hour ageing since installation')
plt.title('Time since installation of type B')
plt.figure()
plt.hist(SN_list[SN_list[PN]=='B'][TSN],bins=20)
plt.ylabel('Frequency')
plt.xlabel('Hour ageing since new')
plt.title('Time since new of type B')
# Out:
# Text(0.5,1,'Time since new of type B')

# %%
plt.hist(SN_list[SN_list[PN]=='C'][TSI],bins=20)
plt.ylabel('Frequency')
plt.xlabel('Hour ageing since installation')
plt.title('Time since installation of type C')
plt.figure()
plt.hist(SN_list[SN_list[PN]=='C'][TSN],bins=20)
plt.ylabel('Frequency')
plt.xlabel('Hour ageing since new')
plt.title('Time since new of type C')
# Out:
# Text(0.5,1,'Time since new of type C')

# %%
print(SN_list.columns)
print(set(SN_list[Status]))
# Out:
# Index(['Part Number', 'Description', 'Serial Number',
#        'Current SN Status Description', 'Company',
#        'Hour ageing Since Installation', 'Hour ageing Since New',
#        'Since New Date'],
#       dtype='object')
# {'In Store U/S', 'On Aircraft', 'In Outside Repair', 'Stored'}

# %%
print(len(SN_list[SN_list[TSI] < SN_list[TSN]][TSI])/np.sum(SN_list[TSI]))
# Out:
# 6.7274246687060175e-06
